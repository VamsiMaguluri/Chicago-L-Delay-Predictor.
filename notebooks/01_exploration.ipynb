# %%
import pandas as pd
import os

# Updated path to match your PyCharm sidebar exactly
file_path = 'data/cta_train_data.csv'

if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print("✅ Success! Data loaded.")
    print(f"Rows collected: {len(df)}")

    # Show the data
    print("\n--- Data Preview ---")
    print(df.head())

    # Show the delay count
    print("\n--- Delay Count (1 = Delayed) ---")
    print(df['isDly'].value_counts())
else:
    print(f"❌ Still can't find the file at: {os.path.abspath(file_path)}")
# Out:
# ✅ Success! Data loaded.
# Rows collected: 4
#
# --- Data Preview ---
#    staId  stpId  staNm                       stpDe   rn    rt  destSt  \
# 0  40590  30115  Damen       Service toward O'Hare  153  Blue   30171
# 1  40590  30116  Damen  Service toward Forest Park  233  Blue   30077
# 2  40590  30116  Damen  Service toward Forest Park  104  Blue   30077
# 3  40590  30115  Damen       Service toward O'Hare  204  Blue   30171
#
#         destNm  trDr                 prdt                 arrT  isApp  isSch  \
# 0       O'Hare     1  2026-02-01T04:57:13  2026-02-01T05:10:13      0      0
# 1  Forest Park     5  2026-02-01T04:57:20  2026-02-01T05:12:20      0      0
# 2  Forest Park     5  2026-02-01T04:55:14  2026-02-01T05:22:14      0      0
# 3       O'Hare     1  2026-02-01T04:56:30  2026-02-01T05:31:30      0      0
#
#    isDly  isFlt  flags       lat       lon  heading      collection_time
# 0      0      0    NaN  41.87557 -87.63357       90  2026-02-01 04:57:44
# ...
